# %% [markdown]
# # Applying Advanced Transformations
# - Victoria White
# - 19 October 2022

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os,json
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ## Loading Data

# %%
powers_df = pd.read_csv('Data/superhero_powers.csv')
powers_df.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
info_df = pd.read_csv('Data/superhero_info.csv')
info_df.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %% [markdown]
# ## Preprocessing: Super Hero Info

# %%
#checking for duplicates
info_df.duplicated().sum()
# Out:
# 0

# %%
#checking for missing values
info_df.isna().sum()
# Out:
# Hero|Publisher    0
# Gender            0
# Race              0
# Alignment         0
# Hair color        0
# Eye color         0
# Skin color        0
# Measurements      0
# dtype: int64

# %%
info_df['Hero|Publisher']
# Out:
# 0               A-Bomb|Marvel Comics
# 1       Abe Sapien|Dark Horse Comics
# 2                 Abin Sur|DC Comics
# 3          Abomination|Marvel Comics
# 4        Absorbing Man|Marvel Comics
#                    ...
# 458       Yellowjacket|Marvel Comics
# 459    Yellowjacket II|Marvel Comics
# 460                Yoda|George Lucas
# 461                Zatanna|DC Comics
# 462                   Zoom|DC Comics
# Name: Hero|Publisher, Length: 463, dtype: object

# %%
#separating Hero|Publisher into two columns
info_df[['Hero', 
         'Publisher']]=info_df['Hero|Publisher'].str.split('|',
                                                           expand=True)
info_df.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %%
#dropping Hero|Publisher column
info_df = info_df.drop(columns=['Hero|Publisher'])
info_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %%
info_df[['Height(cm)', 'Weight(kg)']] = info_df['Measurements'].str.split(',',
                                                                 expand=True)
info_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher             Height(cm)              Weight(kg)
# 0      Marvel Comics  {'Height': '203.0 cm'   'Weight': '441.0 kg'}
# 1  Dark Horse Comics  {'Height': '191.0 cm'    'Weight': '65.0 kg'}
# 2          DC Comics  {'Height': '185.0 cm'    'Weight': '90.0 kg'}
# 3      Marvel Comics  {'Height': '203.0 cm'   'Weight': '441.0 kg'}
# 4      Marvel Comics  {'Height': '193.0 cm'   'Weight': '122.0 kg'}

# %%
info_df = info_df.drop(columns=['Measurements'])
info_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher             Height(cm)  \
# 0         A-Bomb      Marvel Comics  {'Height': '203.0 cm'
# 1     Abe Sapien  Dark Horse Comics  {'Height': '191.0 cm'
# 2       Abin Sur          DC Comics  {'Height': '185.0 cm'
# 3    Abomination      Marvel Comics  {'Height': '203.0 cm'
# 4  Absorbing Man      Marvel Comics  {'Height': '193.0 cm'
#
#                Weight(kg)
# 0   'Weight': '441.0 kg'}
# 1    'Weight': '65.0 kg'}
# 2    'Weight': '90.0 kg'}
# 3   'Weight': '441.0 kg'}
# 4   'Weight': '122.0 kg'}

# %%
replace_height = ["{", "'", "Height", ":", " ", "cm", ".0"]
for char in replace_height:
    info_df['Height(cm)'] = info_df['Height(cm)'].str.replace(char, '',
                                                           regex=False)
info_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher Height(cm)              Weight(kg)
# 0         A-Bomb      Marvel Comics        203   'Weight': '441.0 kg'}
# 1     Abe Sapien  Dark Horse Comics        191    'Weight': '65.0 kg'}
# 2       Abin Sur          DC Comics        185    'Weight': '90.0 kg'}
# 3    Abomination      Marvel Comics        203   'Weight': '441.0 kg'}
# 4  Absorbing Man      Marvel Comics        193   'Weight': '122.0 kg'}

# %%
replace_weight = ["'", "}", "Weight", " ", ":", "kg", ".0"]
for char in replace_weight:
    info_df['Weight(kg)'] = info_df['Weight(kg)'].str.replace(char, '',
                                                           regex=False)
info_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher Height(cm) Weight(kg)
# 0         A-Bomb      Marvel Comics        203        441
# 1     Abe Sapien  Dark Horse Comics        191         65
# 2       Abin Sur          DC Comics        185         90
# 3    Abomination      Marvel Comics        203        441
# 4  Absorbing Man      Marvel Comics        193        122

# %% [markdown]
# ## Preprocessing Super Hero Powers

# %%
powers_df.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
#checking for duplicates
powers_df.duplicated().sum()
# Out:
# 0

# %%
#checking for missing values
powers_df.isna().sum()
# Out:
# hero_names    0
# Powers        0
# dtype: int64

# %%
powers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   hero_names  667 non-null    object
#  1   Powers      667 non-null    object
# dtypes: object(2)
# memory usage: 10.5+ KB

# %%
powers_df['Powers'].str.split(',')
powers_df.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
powers_df['Powers_Split'] = powers_df['Powers'].str.split(',',
                                                         expand=False)
powers_df.head()
# Out:
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...
#
#                                         Powers_Split
# 0    [Agility, Super Strength, Stamina, Super Speed]
# 1  [Accelerated Healing, Durability, Longevity, S...
# 2  [Agility, Accelerated Healing, Cold Resistance...
# 3                               [Lantern Power Ring]
# 4  [Accelerated Healing, Intelligence, Super Stre...

# %%
powers_df['Powers_Split'].value_counts()
# Out:
# [Intelligence]                                                                                                                                                                                                                                                                          8
# [Durability, Super Strength]                                                                                                                                                                                                                                                            5
# [Agility, Stealth, Marksmanship, Weapons Master, Stamina]                                                                                                                                                                                                                               4
# [Marksmanship]                                                                                                                                                                                                                                                                          4
# [Teleportation]                                                                                                                                                                                                                                                                         4
#                                                                                                                                                                                                                                                                                        ..
# [Accelerated Healing, Flight, Telepathy, Energy Blasts, Teleportation, Telekinesis, Astral Projection, Psionic Powers, Mind Blast, Regeneration, Illusions, Resurrection]                                                                                                               1
# [Flight, Telepathy, Animal Oriented Powers, Gliding]                                                                                                                                                                                                                                    1
# [Accelerated Healing, Durability, Energy Absorption, Flight, Super Strength, Telepathy, Energy Blasts, Size Changing, Super Speed, Darkforce Manipulation, Enhanced Senses, Phasing, Invulnerability, Self-Sustenance, Gravity Control, Energy Manipulation, Time Travel, Illusions]    1
# [Agility, Accelerated Healing, Super Strength, Super Speed, Animal Oriented Powers, Enhanced Senses, Jump, Reflexes, Natural Weapons]                                                                                                                                                   1
# [Super Speed, Intangibility, Time Travel, Time Manipulation]                                                                                                                                                                                                                            1
# Name: Powers_Split, Length: 608, dtype: int64

# %%
powers_exploded = powers_df.explode('Powers_Split')
powers_exploded[['hero_names', 'Powers', 'Powers_Split']].head()
# Out:
#   hero_names                                             Powers  \
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1     A-Bomb  Accelerated Healing,Durability,Longevity,Super...
#
#           Powers_Split
# 0              Agility
# 0       Super Strength
# 0              Stamina
# 0          Super Speed
# 1  Accelerated Healing

# %%
cols_to_make = powers_exploded['Powers_Split'].dropna().unique()
cols_to_make
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
#        'Enhanced Senses', 'Jump', 'Shapeshifting', 'Elasticity',
#        'Substance Secretion', 'Enhanced Hearing', 'Adaptation', 'Gliding',
#        'Natural Weapons', 'Wallcrawling', 'Vision - Thermal',
#        'Power Augmentation', 'Cryokinesis', 'Duplication',
#        'Weapon-based Powers', 'Fire Control', 'Enhanced Memory',
#        'Energy Constructs', 'Power Absorption', 'Time Travel',
#        'Enhanced Smell', 'Water Control', 'Vision - Telescopic',
#        'Magnetism', 'Vision - Microscopic', 'Vision - Night',
#        'Vision - Heat', 'Vision - X-Ray', 'Psionic Powers',
#        'Toxin and Disease Resistance', 'Animal Attributes',
#        'Animal Oriented Powers', 'Toxin and Disease Control', 'Empathy',
#        'Animal Control', 'Darkforce Manipulation', 'Time Manipulation',
#        'Reality Warping', 'Web Creation', 'Symbiote Costume',
#        'Telekinesis', 'Levitation', 'Biokinesis', 'Sonar',
#        'Enhanced Touch', 'Seismic Power', 'Energy Armor',
#        'Omnilingualism', 'Radiation Immunity', 'Density Control',
#        'Light Control', 'Illumination', 'Molecular Combustion',
#        'Astral Travel', 'Precognition', 'Intangibility', 'Illusions',
#        'Audio Control', 'Sonic Scream', 'Peak Human Condition',
#        'Vision - Infrared', 'Dexterity', 'Omnitrix', 'Omnipotent',
#        'Possession', 'Energy Resistance', 'Vision - Cryo', 'Mind Control',
#        'Mind Blast', 'Clairvoyance', 'Probability Manipulation',
#        'Death Touch', 'Electrokinesis', 'Gravity Control',
#        'Technopath/Cyberpath', 'Radar Sense', 'Astral Projection',
#        'Cloaking', 'Telepathy Resistance', 'Mind Control Resistance',
#        'Hyperkinesis', 'Spatial Awareness', 'Radiation Control',
#        'Radiation Absorption', 'Magic Resistance', 'Element Control',
#        'Plant Control', 'Terrakinesis', 'Power Sense', 'Wind Control',
#        'Qwardian Power Ring', 'Echolocation', 'Resurrection', 'The Force',
#        'Summoning', 'Banish', 'Molecular Dissipation',
#        'Electrical Transport', 'Speed Force', 'Grim Reaping',
#        'Portal Creation', 'Vitakinesis', 'Projection', 'Insanity',
#        'Photographic Reflexes', 'Anti-Gravity', 'Thirstokinesis',
#        'Power Nullifier', 'Weather Control', 'Omnipresent', 'Omniscient',
#        'Hair Manipulation', 'Nova Force', 'Odin Force', 'Phoenix Force',
#        'Intuitive aptitude', 'Melting', 'Changing Armor'], dtype=object)

# %%
for col in cols_to_make:
    powers_df[col] = powers_df['Powers'].str.contains(col)
powers_df.head()
# Out:
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\2636762965.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col)
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...
#
#                                         Powers_Split  Agility  Super Strength  \
# 0    [Agility, Super Strength, Stamina, Super Speed]     True            True
# 1  [Accelerated Healing, Durability, Longevity, S...    False            True
# 2  [Agility, Accelerated Healing, Cold Resistance...     True            True
# 3                               [Lantern Power Ring]    False           False
# 4  [Accelerated Healing, Intelligence, Super Stre...    False            True
#
#    Stamina  Super Speed  Accelerated Healing  Durability  Longevity  ...  \
# 0     True         True                False       False      False  ...
# 1     True        False                 True        True       True  ...
# 2     True        False                 True        True       True  ...
# 3    False        False                False       False      False  ...
# 4     True         True                 True       False      False  ...
#
#    Weather Control  Omnipresent  Omniscient  Hair Manipulation  Nova Force  \
# 0            False        False       False              False       False
# 1            False        False       False              False       False
# 2            False        False       False              False       False
# 3            False        False       False              False       False
# 4            False        False       False              False       False
#
#    Odin Force  Phoenix Force  Intuitive aptitude  Melting  Changing Armor
# 0       False          False               False    False           False
# 1       False          False               False    False           False
# 2       False          False               False    False           False
# 3       False          False               False    False           False
# 4       False          False               False    False           False
#
# [5 rows x 170 columns]

# %%
left_df = info_df
right_df = powers_df
final = pd.merge(left_df, right_df, left_on='Hero', right_on='hero_names')
final
# Out:
#      Gender               Race Alignment        Hair color Eye color  \
# 0      Male              Human      good           No Hair    yellow
# 1      Male      Icthyo Sapien      good           No Hair      blue
# 2      Male            Ungaran      good           No Hair      blue
# 3      Male  Human / Radiation       bad           No Hair     green
# 4      Male              Human       bad           No Hair      blue
# ..      ...                ...       ...               ...       ...
# 458    Male              Human      good             Blond      blue
# 459  Female              Human      good  Strawberry Blond      blue
# 460    Male     Yoda's species      good             White     brown
# 461  Female              Human      good             Black      blue
# 462    Male            Unknown       bad             Brown       red
#
#     Skin color             Hero          Publisher Height(cm) Weight(kg)  ...  \
# 0      Unknown           A-Bomb      Marvel Comics        203        441  ...
# 1         blue       Abe Sapien  Dark Horse Comics        191         65  ...
# 2          red         Abin Sur          DC Comics        185         90  ...
# 3      Unknown      Abomination      Marvel Comics        203        441  ...
# 4      Unknown    Absorbing Man      Marvel Comics        193        122  ...
# ..         ...              ...                ...        ...        ...  ...
# 458    Unknown     Yellowjacket      Marvel Comics        183         83  ...
# 459    Unknown  Yellowjacket II      Marvel Comics        165         52  ...
# 460      green             Yoda       George Lucas         66         17  ...
# 461    Unknown          Zatanna          DC Comics        170         57  ...
# 462    Unknown             Zoom          DC Comics        185         81  ...
#
#     Weather Control Omnipresent Omniscient  Hair Manipulation  Nova Force  \
# 0             False       False      False              False       False
# 1             False       False      False              False       False
# 2             False       False      False              False       False
# 3             False       False      False              False       False
# 4             False       False      False              False       False
# ..              ...         ...        ...                ...         ...
# 458           False       False      False              False       False
# 459           False       False      False              False       False
# 460           False       False      False              False       False
# 461            True       False      False              False       False
# 462           False       False      False              False       False
#
#      Odin Force  Phoenix Force  Intuitive aptitude  Melting  Changing Armor
# 0         False          False               False    False           False
# 1         False          False               False    False           False
# 2         False          False               False    False           False
# 3         False          False               False    False           False
# 4         False          False               False    False           False
# ..          ...            ...                 ...      ...             ...
# 458       False          False               False    False           False
# 459       False          False               False    False           False
# 460       False          False               False    False           False
# 461       False          False               False    False           False
# 462       False          False               False    False           False
#
# [463 rows x 180 columns]

# %% [markdown]
# ## Compare the Average Weight
# - Comparing the average weight of heroes with and without super speed.

# %%
#creating filter for heroes with and without Super Speed
has_super_speed_filter = final['Super Speed'] == True
no_super_speed_filter = final['Super Speed'] == False

# %%
#applying filter on dataframe
has_super_speed = final.loc[has_super_speed_filter, :]
has_super_speed
# Out:
#      Gender               Race Alignment Hair color Eye color Skin color  \
# 3      Male  Human / Radiation       bad    No Hair     green    Unknown
# 5      Male              Human      good      Blond      blue    Unknown
# 8      Male            Unknown       bad      White      blue    Unknown
# 9      Male             Cyborg       bad      Black     brown    Unknown
# 10     Male            Unknown      good      Blond      blue    Unknown
# ..      ...                ...       ...        ...       ...        ...
# 453  Female           Demi-God      good      Blond      blue    Unknown
# 454    Male            Unknown      good      Black       red    Unknown
# 455  Female             Amazon      good      Black      blue    Unknown
# 460    Male     Yoda's species      good      White     brown      green
# 462    Male            Unknown       bad      Brown       red    Unknown
#
#              Hero      Publisher Height(cm) Weight(kg)  ... Weather Control  \
# 3     Abomination  Marvel Comics        203        441  ...           False
# 5    Adam Strange      DC Comics        185         88  ...           False
# 8      Air-Walker  Marvel Comics        188        108  ...           False
# 9            Ajax  Marvel Comics        193         90  ...           False
# 10     Alan Scott      DC Comics        180         90  ...           False
# ..            ...            ...        ...        ...  ...             ...
# 453   Wonder Girl      DC Comics        165         51  ...           False
# 454    Wonder Man  Marvel Comics        188        171  ...           False
# 455  Wonder Woman      DC Comics        183         74  ...           False
# 460          Yoda   George Lucas         66         17  ...           False
# 462          Zoom      DC Comics        185         81  ...           False
#
#     Omnipresent Omniscient  Hair Manipulation  Nova Force  Odin Force  \
# 3         False      False              False       False       False
# 5         False      False              False       False       False
# 8         False      False              False       False       False
# 9         False      False              False       False       False
# 10        False      False              False       False       False
# ..          ...        ...                ...         ...         ...
# 453       False      False              False       False       False
# 454       False      False              False       False       False
# 455       False      False              False       False       False
# 460       False      False              False       False       False
# 462       False      False              False       False       False
#
#      Phoenix Force  Intuitive aptitude  Melting  Changing Armor
# 3            False               False    False           False
# 5            False               False    False           False
# 8            False               False    False           False
# 9            False               False    False           False
# 10           False               False    False           False
# ..             ...                 ...      ...             ...
# 453          False               False    False           False
# 454          False               False    False           False
# 455          False               False    False           False
# 460          False               False    False           False
# 462          False               False    False           False
#
# [198 rows x 180 columns]

# %%
#applying filter on dataframe
no_super_speed = final.loc[no_super_speed_filter, :]
no_super_speed
# Out:
#      Gender            Race Alignment        Hair color Eye color Skin color  \
# 0      Male           Human      good           No Hair    yellow    Unknown
# 1      Male   Icthyo Sapien      good           No Hair      blue       blue
# 2      Male         Ungaran      good           No Hair      blue        red
# 4      Male           Human       bad           No Hair      blue    Unknown
# 6      Male           Human      good             Brown     brown    Unknown
# ..      ...             ...       ...               ...       ...        ...
# 456  Female  Mutant / Clone      good             Black     green    Unknown
# 457    Male         Unknown      good             Brown      blue    Unknown
# 458    Male           Human      good             Blond      blue    Unknown
# 459  Female           Human      good  Strawberry Blond      blue    Unknown
# 461  Female           Human      good             Black      blue    Unknown
#
#                 Hero          Publisher Height(cm) Weight(kg)  ...  \
# 0             A-Bomb      Marvel Comics        203        441  ...
# 1         Abe Sapien  Dark Horse Comics        191         65  ...
# 2           Abin Sur          DC Comics        185         90  ...
# 4      Absorbing Man      Marvel Comics        193        122  ...
# 6          Agent Bob      Marvel Comics        178         81  ...
# ..               ...                ...        ...        ...  ...
# 456             X-23      Marvel Comics        155         50  ...
# 457            X-Man      Marvel Comics        175         61  ...
# 458     Yellowjacket      Marvel Comics        183         83  ...
# 459  Yellowjacket II      Marvel Comics        165         52  ...
# 461          Zatanna          DC Comics        170         57  ...
#
#     Weather Control Omnipresent Omniscient  Hair Manipulation  Nova Force  \
# 0             False       False      False              False       False
# 1             False       False      False              False       False
# 2             False       False      False              False       False
# 4             False       False      False              False       False
# 6             False       False      False              False       False
# ..              ...         ...        ...                ...         ...
# 456           False       False      False              False       False
# 457           False       False      False              False       False
# 458           False       False      False              False       False
# 459           False       False      False              False       False
# 461            True       False      False              False       False
#
#      Odin Force  Phoenix Force  Intuitive aptitude  Melting  Changing Armor
# 0         False          False               False    False           False
# 1         False          False               False    False           False
# 2         False          False               False    False           False
# 4         False          False               False    False           False
# 6         False          False               False    False           False
# ..          ...            ...                 ...      ...             ...
# 456       False          False               False    False           False
# 457       False          False               False    False           False
# 458       False          False               False    False           False
# 459       False          False               False    False           False
# 461       False          False               False    False           False
#
# [265 rows x 180 columns]

# %%
#change dtype from object for Weight
has_super_speed['Weight(kg)'] = has_super_speed['Weight(kg)'].astype(float)
no_super_speed['Weight(kg)'] = no_super_speed['Weight(kg)'].astype(float)
# Out:
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\3861637849.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   has_super_speed['Weight(kg)'] = has_super_speed['Weight(kg)'].astype(float)
# C:\Users\mrsvw\AppData\Local\Temp\ipykernel_23556\3861637849.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_super_speed['Weight(kg)'] = no_super_speed['Weight(kg)'].astype(float)

# %%
has_super_speed['Weight(kg)'].mean()
# Out:
# 129.40404040404042

# %%
no_super_speed['Weight(kg)'].mean()
# Out:
# 101.77358490566037

# %% [markdown]
# ### Average Weight
# ####  The average weight of heroes with the power super speed is 129.4kg. The average weight of heroes without the power of super speed is 101.77kg.

# %% [markdown]
# ## Finding Average Height of Heroes by Publisher

# %%
#finding how many different publishers there are
final['Publisher'].value_counts()
# Out:
# Marvel Comics        297
# DC Comics            138
# Dark Horse Comics     11
# George Lucas           5
# Team Epic TV           4
# Shueisha               4
# Star Trek              2
# Unknown                1
# Image Comics           1
# Name: Publisher, dtype: int64

# %%
#changing height(cm) to numeric
final['Height(cm)'] = final['Height(cm)'].astype(float)

# %%
#creating filters for different publishers
marvel_filter = final["Publisher"] == 'Marvel Comics'
dc_filter = final["Publisher"] == 'DC Comics'
dark_horse_filter = final["Publisher"] == 'Dark Horse Comics'
george_lucas_filter = final["Publisher"] == 'George Lucas'
team_epic_filter = final["Publisher"] == 'Team Epic TV'
shueisha_filter = final["Publisher"] == 'Shueisha'
star_trek_filter = final["Publisher"] == 'Star Trek'
unknown_filter = final["Publisher"] == 'Unknown'
image_comics_filter = final["Publisher"] == 'Image Comics'

# %%
#finding average height
marvel = final.loc[marvel_filter, :]
marvel['Height(cm)'].mean()
# Out:
# 191.54612794612794

# %%
#finding average height
dc = final.loc[dc_filter,:]
dc['Height(cm)'].mean()
# Out:
# 181.92391304347825

# %%
#finding average height
dark_horse = final.loc[dark_horse_filter,:]
dark_horse['Height(cm)'].mean()
# Out:
# 176.9090909090909

# %%
#finding average height
george_lucas= final.loc[george_lucas_filter,:]
george_lucas['Height(cm)'].mean()
# Out:
# 159.6

# %%
#finding average height
team_epic = final.loc[team_epic_filter,:]
team_epic['Height(cm)'].mean()
# Out:
# 180.75

# %%
#finding average height
shueisha= final.loc[shueisha_filter,:]
shueisha['Height(cm)'].mean()
# Out:
# 171.5

# %%
#finding average height
star_trek = final.loc[star_trek_filter,:]
star_trek['Height(cm)'].mean()
# Out:
# 181.5

# %%
#finding average height
unknown = final.loc[unknown_filter,:]
unknown['Height(cm)'].mean()
# Out:
# 178.0

# %%
#finding average height
image_comics_filter
image_comics = final.loc[image_comics_filter,:]
image_comics['Height(cm)'].mean()
# Out:
# 211.0

# %% [markdown]
# ### Average Height of Heroes by Publisher
# #### The average heights(cm) of super heroes based on publisher are:
# - Marvel: 191.55cm
# - DC Comics: 181.92cm
# - Dark Horse Comics: 176.91cm
# - George Lucas:159.60cm
# - Team Epic TV: 180.75cm
# - Shueisha:171.5cm
# - Star Trek:181.5cm
# - Unknown:178.0cm
# - Image Comics: 211.0cm
